# %%
#Importing the required libs for the exercise

from os import path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from ydata_synthetic.synthesizers import ModelParameters
from ydata_synthetic.preprocessing.timeseries import processed_stock
from ydata_synthetic.synthesizers.timeseries import TimeGAN
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 9>()
#       5 import numpy as np
#       6 import matplotlib.pyplot as plt
# ----> 9 from ydata_synthetic.synthesizers import ModelParameters
#      10 from ydata_synthetic.preprocessing.timeseries import processed_stock
#      11 from ydata_synthetic.synthesizers.timeseries import TimeGAN
#
# File ~\AppData\Roaming\Python\Python38\site-packages\ydata_synthetic\synthesizers\__init__.py:1, in <module>
# ----> 1 from ydata_synthetic.synthesizers.gan import ModelParameters, TrainParameters
#
# File ~\AppData\Roaming\Python\Python38\site-packages\ydata_synthetic\synthesizers\gan.py:26, in <module>
#      22 from ydata_synthetic.preprocessing.regular.processor import (
#      23     RegularDataProcessor, RegularModels)
#      24 from ydata_synthetic.preprocessing.timeseries.timeseries_processor import (
#      25     TimeSeriesDataProcessor, TimeSeriesModels)
# ---> 26 from ydata_synthetic.preprocessing.regular.ctgan_processor import CTGANDataProcessor
#      27 from ydata_synthetic.synthesizers.saving_keras import make_keras_picklable
#      29 _model_parameters = ['batch_size', 'lr', 'betas', 'layers_dim', 'noise_dim',
#      30                      'n_cols', 'seq_len', 'condition', 'n_critic', 'n_features',
#      31                      'tau_gs', 'generator_dims', 'critic_dims', 'l2_scale',
#      32                      'latent_dim', 'gp_lambda', 'pac']
#
# File ~\AppData\Roaming\Python\Python38\site-packages\ydata_synthetic\preprocessing\regular\ctgan_processor.py:9, in <module>
#       7 import numpy as np
#       8 from sklearn.exceptions import NotFittedError, ConvergenceWarning
# ----> 9 from sklearn.utils._testing import ignore_warnings
#      10 from sklearn.mixture import BayesianGaussianMixture
#      11 from sklearn.preprocessing import OneHotEncoder
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\_testing.py:397, in <module>
#     394 skip_if_32bit = pytest.mark.skipif(_IS_32BIT, reason="skipped on 32bit platforms")
#     395 fails_if_pypy = pytest.mark.xfail(IS_PYPY, reason="not compatible with PyPy")
#     396 fails_if_unstable_openblas = pytest.mark.xfail(
# --> 397     _in_unstable_openblas_configuration(),
#     398     reason="OpenBLAS is unstable for this configuration",
#     399 )
#     400 skip_if_no_parallel = pytest.mark.skipif(
#     401     not joblib.parallel.mp, reason="joblib is in serial mode"
#     402 )
#     404 #  Decorator for tests involving both BLAS calls and multiprocessing.
#     405 #
#     406 #  Under POSIX (e.g. Linux or OSX), using multiprocessing in conjunction
#    (...)
#     420 #  errors on interactively defined functions. It therefore not enabled by
#     421 #  default.
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\__init__.py:90, in _in_unstable_openblas_configuration()
#      87 import numpy  # noqa
#      88 import scipy  # noqa
# ---> 90 modules_info = threadpool_info()
#      92 open_blas_used = any(info["internal_api"] == "openblas" for info in modules_info)
#      93 if not open_blas_used:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\fixes.py:150, in threadpool_info()
#     148     return controller.info()
#     149 else:
# --> 150     return threadpoolctl.threadpool_info()
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\threadpoolctl.py:124, in threadpool_info()
#     107 @_format_docstring(USER_APIS=list(_ALL_USER_APIS),
#     108                    INTERNAL_APIS=_ALL_INTERNAL_APIS)
#     109 def threadpool_info():
#     110     """Return the maximal number of threads for each detected library.
#     111
#     112     Return a list with all the supported modules that have been found. Each
#    (...)
#     122     In addition, each module may contain internal_api specific entries.
#     123     """
# --> 124     return _ThreadpoolInfo(user_api=_ALL_USER_APIS).todicts()
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\threadpoolctl.py:340, in _ThreadpoolInfo.__init__(self, user_api, prefixes, modules)
#     337     self.user_api = [] if user_api is None else user_api
#     339     self.modules = []
# --> 340     self._load_modules()
#     341     self._warn_if_incompatible_openmp()
#     342 else:
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\threadpoolctl.py:373, in _ThreadpoolInfo._load_modules(self)
#     371     self._find_modules_with_dyld()
#     372 elif sys.platform == "win32":
# --> 373     self._find_modules_with_enum_process_module_ex()
#     374 else:
#     375     self._find_modules_with_dl_iterate_phdr()
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\threadpoolctl.py:485, in _ThreadpoolInfo._find_modules_with_enum_process_module_ex(self)
#     482         filepath = buf.value
#     484         # Store the module if it is supported and selected
# --> 485         self._make_module_from_path(filepath)
#     486 finally:
#     487     kernel_32.CloseHandle(h_process)
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\threadpoolctl.py:515, in _ThreadpoolInfo._make_module_from_path(self, filepath)
#     513 if prefix in self.prefixes or user_api in self.user_api:
#     514     module_class = globals()[module_class]
# --> 515     module = module_class(filepath, prefix, user_api, internal_api)
#     516     self.modules.append(module)
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\threadpoolctl.py:606, in _Module.__init__(self, filepath, prefix, user_api, internal_api)
#     604 self.internal_api = internal_api
#     605 self._dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
# --> 606 self.version = self.get_version()
#     607 self.num_threads = self.get_num_threads()
#     608 self._get_extra_info()
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\threadpoolctl.py:646, in _OpenBLASModule.get_version(self)
#     643 get_config = getattr(self._dynlib, "openblas_get_config",
#     644                      lambda: None)
#     645 get_config.restype = ctypes.c_char_p
# --> 646 config = get_config().split()
#     647 if config[0] == b"OpenBLAS":
#     648     return config[1].decode("utf-8")
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
#Specific to TimeGANs
seq_len=24
n_seq = 6
hidden_dim=24
gamma=1

noise_dim = 32
dim = 128
batch_size = 128

log_step = 100
learning_rate = 5e-4

gan_args = ModelParameters(batch_size=batch_size,
                           lr=learning_rate,
                           noise_dim=noise_dim,
                           layers_dim=dim)
